# %% [markdown]
# # Steering results

# %%
import torch
import os
import sys
import numpy as np
import pandas as pd

sys.path.append('.')
sys.path.append('..')

# %%
model_name = "qwen-3-32b"
layer = 32
base_dir = f"/workspace/{model_name}"
