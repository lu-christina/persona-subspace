# %% [markdown]
# # Compare contrast vectors

# %%
import torch
import os
import sys
import numpy as np

sys.path.append('.')
sys.path.append('..')

# %%
model_name = "gemma-2-27b"
layer = 22
total_layers = 46
base_dir = f"/workspace/{model_name}"

# %%
default_all_layers = torch.load(f"{base_dir}/roles_240/default_vectors.pt")['activations']['default_1']

# %%
role_results = torch.load(f"{base_dir}/roles_240/pca/layer{layer}_mean_pos23.pt", weights_only=False)
trait_results = torch.load(f"{base_dir}/traits_240/pca/layer{layer}_mean_pos-neg50.pt", weights_only=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 role_results = torch.load(f"{base_dir}/roles_240/pca/layer{layer}_mean_pos23.pt", weights_only=False)
#       2 trait_results = torch.load(f"{base_dir}/traits_240/pca/layer{layer}_mean_pos-neg50.pt", weights_only=False)
#
# File ~/git/persona-subspace/.venv/lib/python3.12/site-packages/torch/serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# File ~/git/persona-subspace/.venv/lib/python3.12/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/git/persona-subspace/.venv/lib/python3.12/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/gemma-2-27b/roles_240/pca/layer22_mean_pos23.pt'

# %%
def get_role_labels(pca_results):
    labels = []
    if 'pos_2' in pca_results['roles'].keys():
        pos_2_roles = [role.replace('_', ' ').title() for role in pca_results['roles']['pos_2']]
        pos_2_roles = [f"{role} (Somewhat RP)" for role in pos_2_roles]
        labels.extend(pos_2_roles)
    if 'pos_3' in pca_results['roles'].keys():
        pos_3_roles = [role.replace('_', ' ').title() for role in pca_results['roles']['pos_3']]
        pos_3_roles = [f"{role} (Fully RP)" for role in pos_3_roles]
        labels.extend(pos_3_roles)
    return labels

role_labels = get_role_labels(role_results)
trait_labels = [trait.replace('_', ' ').title() for trait in trait_results['traits']['pos_neg_50']]

# %%
pos_2_roles = []
pos_2_vectors = []
pos_3_roles = []
pos_3_vectors = []

pos_2_roles.extend(role_results['roles']['pos_2'])
pos_3_roles.extend(role_results['roles']['pos_3'])
pos_2_vectors.extend(role_results['vectors']['pos_2'])
pos_3_vectors.extend(role_results['vectors']['pos_3'])
